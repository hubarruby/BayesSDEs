# %%
import os

from IPython.display import display

from fredholm_plotting import *
from fredholm_utils import estimated_b_function_matrix

# %%
def get_data_make_plots(dirpath, range_linspace=[-5,5], plotting_y_lim=None):
    # find all the files in the directory given
    filenames = []
    for filename in os.listdir(dirpath):
        if os.path.isfile(os.path.join(dirpath, filename)):
            filenames.append(filename)

    dict_list = get_results_dictionaries(filenames, filepath=dirpath)
    meta = metadata_table(dict_list)
    display(meta)

    compare_betas(dict_list)
    range_linspace = range_linspace
    b_mat = estimated_b_function_matrix(
        range_linspace=range_linspace,
        init_data=dict_list[0]['init_data'],
        kernel = gauss_kernel,
        known_b=dict_list[0]['known_b'],
        y_domain=[dict_list[0]['meta_data']['y_domain'][0], dict_list[0]['meta_data']['y_domain'][1]],
        int_n = 5000
    )
    plot_bbar_estimates(dict_list, b_mat, y_lim=plotting_y_lim)

# %% [markdown]
# # Plots for simulations where Pi = truncnorm(1,10) truncated at -100,100...
#
# ## Plots for b(x, y) = (x - x^3)y (b1):

# %%
get_data_make_plots('fredholm_results/results0/')
# Out:
#           pi     scale  loc  a_trunc  b_trunc  beta_distribution_a  \
# 0  truncnorm  3.162278    1     -100      100                    3
# 1  truncnorm  3.162278    1     -100      100                    3
# 2  truncnorm  3.162278    1     -100      100                    3
# 3  truncnorm  3.162278    1     -100      100                    3
#
#    beta_distribution_b  diffusion  t_delta  t_end  ...       y_domain  \
# 0                    2          1     0.05  100.0  ...  (-50.0, 50.0)
# 1                    2          1     0.05  100.0  ...  (-50.0, 50.0)
# 2                    2          1     0.05  100.0  ...  (-50.0, 50.0)
# 3                    2          1     0.05  100.0  ...  (-50.0, 50.0)
#
#                                     results_filepath  local_gig_a  \
# 0  fredholm/fredholm_results/results0/gig01_01_-1...          0.1
# 1  fredholm/fredholm_results/results0/gig01_05_-3...          0.1
# 2    fredholm/fredholm_results/results0/lasso_b1.pkl          2.0
# ...

# %%
# there is some issue with these results
# all the priors give the same estimated values.
# some values of the estimated coefficients are extremely high
get_data_make_plots('fredholm_results/results1/')
# Out:
#           pi     scale  loc  a_trunc  b_trunc  beta_distribution_a  \
# 0  truncnorm  3.162278    1     -100      100                    3
# 1  truncnorm  3.162278    1     -100      100                    3
# 2  truncnorm  3.162278    1     -100      100                    3
# 3  truncnorm  3.162278    1     -100      100                    3
#
#    beta_distribution_b  diffusion  t_delta  t_end  ...       y_domain  \
# 0                    2          1     0.05  100.0  ...  (-50.0, 50.0)
# 1                    2          1     0.05  100.0  ...  (-50.0, 50.0)
# 2                    2          1     0.05  100.0  ...  (-50.0, 50.0)
# 3                    2          1     0.05  100.0  ...  (-50.0, 50.0)
#
#                                     results_filepath  local_gig_a  \
# 0  fredholm/fredholm_results/results1/gig01_01_-1...          0.1
# 1  fredholm/fredholm_results/results1/gig01_05_-3...          0.1
# 2    fredholm/fredholm_results/results1/lasso_b2.pkl          2.0
# ...

# %%
get_data_make_plots('fredholm_results/results2/', plotting_y_lim=(-50,50))
# Out:
#           pi     scale  loc  a_trunc  b_trunc  beta_distribution_a  \
# 0  truncnorm  3.162278    1     -100      100                    3
# 1  truncnorm  3.162278    1     -100      100                    3
# 2  truncnorm  3.162278    1     -100      100                    3
# 3  truncnorm  3.162278    1     -100      100                    3
#
#    beta_distribution_b  diffusion  t_delta  t_end  ...       y_domain  \
# 0                    2          1     0.05  100.0  ...  (-50.0, 50.0)
# 1                    2          1     0.05  100.0  ...  (-50.0, 50.0)
# 2                    2          1     0.05  100.0  ...  (-50.0, 50.0)
# 3                    2          1     0.05  100.0  ...  (-50.0, 50.0)
#
#                                     results_filepath  local_gig_a  \
# 0  fredholm/fredholm_results/results2/gig01_01_-1...          0.1
# 1  fredholm/fredholm_results/results2/gig01_05_-3...          0.1
# 2  fredholm/fredholm_results/results2/lasso_b_gam...          2.0
# ...

# %%
# The above is interesting. Maybe the training data only is positive, making the left side harder to learn?
# Another odd thing about the above graph is that the numerical integration does not work for negative values of x
plt.hist(get_results_dictionaries(['lasso_b_gamma1.pkl'], filepath='fredholm_results/results2/')[0]['init_data'])
plt.title('Distribution of data generated by b=9/(x+y^2) - 5')
plt.show()

# %%
get_data_make_plots('fredholm_results/results3/', plotting_y_lim=(-50,50))
# Out:
#           pi     scale  loc  a_trunc  b_trunc  beta_distribution_a  \
# 0  truncnorm  3.162278    1     -100      100                    3
# 1  truncnorm  3.162278    1     -100      100                    3
# 2  truncnorm  3.162278    1     -100      100                    3
# 3  truncnorm  3.162278    1     -100      100                    3
#
#    beta_distribution_b  diffusion  t_delta  t_end  ...       y_domain  \
# 0                    2          1     0.05  100.0  ...  (-50.0, 50.0)
# 1                    2          1     0.05  100.0  ...  (-50.0, 50.0)
# 2                    2          1     0.05  100.0  ...  (-50.0, 50.0)
# 3                    2          1     0.05  100.0  ...  (-50.0, 50.0)
#
#                                     results_filepath  local_gig_a  \
# 0  fredholm/fredholm_results/results3/gig01_01_-1...          0.1
# 1  fredholm/fredholm_results/results3/gig01_05_-3...          0.1
# 2  fredholm/fredholm_results/results3/lasso_b_gam...          2.0
# ...

# %%
get_data_make_plots('fredholm_results/results4/')
# Out:
#      pi     scale  loc  a_trunc  b_trunc  beta_distribution_a  \
# 0  beta  3.162278    1     -100      100                  3.0
# 1  beta  3.162278    1     -100      100                  3.0
# 2  beta  3.162278    1     -100      100                  3.0
# 3  beta  3.162278    1     -100      100                  3.0
#
#    beta_distribution_b  diffusion  t_delta  t_end  ...       y_domain  \
# 0                  2.0          1     0.05  100.0  ...  (-50.0, 50.0)
# 1                  2.0          1     0.05  100.0  ...  (-50.0, 50.0)
# 2                  2.0          1     0.05  100.0  ...  (-50.0, 50.0)
# 3                  2.0          1     0.05  100.0  ...  (-50.0, 50.0)
#
#                                     results_filepath  local_gig_a  \
# 0  fredholm/fredholm_results/results4/gig01_01_-1...          0.1
# 1  fredholm/fredholm_results/results4/gig01_05_-3...          0.1
# 2  fredholm/fredholm_results/results4/lasso_b1_pi...          2.0
# ...

# %%
get_data_make_plots('fredholm_results/results5/')
# Out:
#      pi     scale  loc  a_trunc  b_trunc  beta_distribution_a  \
# 0  beta  3.162278    1     -100      100                  3.0
# 1  beta  3.162278    1     -100      100                  3.0
# 2  beta  3.162278    1     -100      100                  3.0
# 3  beta  3.162278    1     -100      100                  3.0
#
#    beta_distribution_b  diffusion  t_delta  t_end  ...       y_domain  \
# 0                  2.0          1     0.05  100.0  ...  (-50.0, 50.0)
# 1                  2.0          1     0.05  100.0  ...  (-50.0, 50.0)
# 2                  2.0          1     0.05  100.0  ...  (-50.0, 50.0)
# 3                  2.0          1     0.05  100.0  ...  (-50.0, 50.0)
#
#                                     results_filepath  local_gig_a  \
# 0  fredholm/fredholm_results/results5/gig01_01_-1...          0.1
# 1  fredholm/fredholm_results/results5/gig01_05_-3...          0.1
# 2  fredholm/fredholm_results/results5/lasso_b2_pi...          2.0
# ...

# %%
get_data_make_plots('fredholm_results/results6/', plotting_y_lim=(-50,50))
# Out:
#      pi     scale  loc  a_trunc  b_trunc  beta_distribution_a  \
# 0  beta  3.162278    1     -100      100                  3.0
# 1  beta  3.162278    1     -100      100                  3.0
# 2  beta  3.162278    1     -100      100                  3.0
# 3  beta  3.162278    1     -100      100                  3.0
#
#    beta_distribution_b  diffusion  t_delta  t_end  ...       y_domain  \
# 0                  2.0          1     0.05  100.0  ...  (-50.0, 50.0)
# 1                  2.0          1     0.05  100.0  ...  (-50.0, 50.0)
# 2                  2.0          1     0.05  100.0  ...  (-50.0, 50.0)
# 3                  2.0          1     0.05  100.0  ...  (-50.0, 50.0)
#
#                                     results_filepath  local_gig_a  \
# 0  fredholm/fredholm_results/results6/gig01_01_-1...          0.1
# 1  fredholm/fredholm_results/results6/gig01_05_-3...          0.1
# 2  fredholm/fredholm_results/results6/lasso_b_gam...          2.0
# ...

# %%
get_data_make_plots('fredholm_results/results7/', plotting_y_lim=(-50,50))
# Out:
#      pi     scale  loc  a_trunc  b_trunc  beta_distribution_a  \
# 0  beta  3.162278    1     -100      100                  3.0
# 1  beta  3.162278    1     -100      100                  3.0
# 2  beta  3.162278    1     -100      100                  3.0
# 3  beta  3.162278    1     -100      100                  3.0
#
#    beta_distribution_b  diffusion  t_delta  t_end  ...       y_domain  \
# 0                  2.0          1     0.05  100.0  ...  (-50.0, 50.0)
# 1                  2.0          1     0.05  100.0  ...  (-50.0, 50.0)
# 2                  2.0          1     0.05  100.0  ...  (-50.0, 50.0)
# 3                  2.0          1     0.05  100.0  ...  (-50.0, 50.0)
#
#                                     results_filepath  local_gig_a  \
# 0  fredholm/fredholm_results/results7/gig01_01_-1...          0.1
# 1  fredholm/fredholm_results/results7/gig01_05_-3...          0.1
# 2  fredholm/fredholm_results/results7/lasso_b_gam...          2.0
# ...

# %%
get_data_make_plots('fredholm_results/results8/')
# Out:
#           pi     scale  loc  a_trunc  b_trunc  beta_distribution_a  \
# 0  truncnorm  3.162278    1     -100      100                    3
# 1  truncnorm  3.162278    1     -100      100                    3
# 2  truncnorm  3.162278    1     -100      100                    3
# 3  truncnorm  3.162278    1     -100      100                    3
#
#    beta_distribution_b  diffusion  t_delta  t_end  ...       y_domain  \
# 0                    2          1     0.05  100.0  ...  (-10.0, 10.0)
# 1                    2          1     0.05  100.0  ...  (-10.0, 10.0)
# 2                    2          1     0.05  100.0  ...  (-10.0, 10.0)
# 3                    2          1     0.05  100.0  ...  (-10.0, 10.0)
#
#                                     results_filepath  local_gig_a  \
# 0  fredholm/fredholm_results/results8/gig01_01_-1...          0.1
# 1  fredholm/fredholm_results/results8/gig01_05_-3...          0.1
# 2  fredholm/fredholm_results/results8/lasso_b2_sm...          2.0
# ...

# %%
get_data_make_plots('fredholm_results/results9/')

# %%
get_data_make_plots('fredholm_results/results10/')
# Out:
#      pi     scale  loc  a_trunc  b_trunc  beta_distribution_a  \
# 0  beta  3.162278    1     -100      100                  3.0
# 1  beta  3.162278    1     -100      100                  3.0
# 2  beta  3.162278    1     -100      100                  3.0
# 3  beta  3.162278    1     -100      100                  3.0
#
#    beta_distribution_b  diffusion  t_delta  t_end  ...       y_domain  \
# 0                  2.0          1     0.05  100.0  ...  (-10.0, 10.0)
# 1                  2.0          1     0.05  100.0  ...  (-10.0, 10.0)
# 2                  2.0          1     0.05  100.0  ...  (-10.0, 10.0)
# 3                  2.0          1     0.05  100.0  ...  (-10.0, 10.0)
#
#                                     results_filepath  local_gig_a  \
# 0  fredholm/fredholm_results/results10/gig01_01_-...          0.1
# 1  fredholm/fredholm_results/results10/gig01_05_-...          0.1
# 2  fredholm/fredholm_results/results10/lasso_b2_p...          2.0
# ...

# %%
plt.hist(get_results_dictionaries(['lasso_b2_pibeta_smally.pkl'], filepath='fredholm_results/results10/')[0]['init_data'])
plt.title('Distribution of data generated by b = (x+y) - (x+y)^3')
plt.show()

# %%
get_data_make_plots('fredholm_results/results11/', plotting_y_lim=(-50,50))
# Out:
#      pi     scale  loc  a_trunc  b_trunc  beta_distribution_a  \
# 0  beta  3.162278    1     -100      100                  3.0
# 1  beta  3.162278    1     -100      100                  3.0
# 2  beta  3.162278    1     -100      100                  3.0
# 3  beta  3.162278    1     -100      100                  3.0
#
#    beta_distribution_b  diffusion  t_delta  t_end  ...       y_domain  \
# 0                  2.0          1     0.05  100.0  ...  (-10.0, 10.0)
# 1                  2.0          1     0.05  100.0  ...  (-10.0, 10.0)
# 2                  2.0          1     0.05  100.0  ...  (-10.0, 10.0)
# 3                  2.0          1     0.05  100.0  ...  (-10.0, 10.0)
#
#                                     results_filepath  local_gig_a  \
# 0  fredholm/fredholm_results/results11/gig01_01_-...          0.1
# 1  fredholm/fredholm_results/results11/gig01_05_-...          0.1
# 2  fredholm/fredholm_results/results11/lasso_b_ga...          2.0
# ...

# %%
plt.hist(get_results_dictionaries(['lasso_b_gamma1_pibeta_smally.pkl'], filepath='fredholm_results/results11/')[0]['init_data'])
plt.title('Distribution of data generated by b = 9/(x+y^2) - 5')
plt.show()
